# %%
# !pip install pandas
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.0/61.0 kB 432.3 kB/s eta 0:00:001m389.8 kB/s eta 0:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.0/13.0 MB 231.2 kB/s eta 0:00:00m eta 0:00:010:00:02
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18.2/18.2 MB 339.4 kB/s eta 0:00:00m eta 0:00:010:00:02
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 505.5/505.5 kB 410.8 kB/s eta 0:00:00m eta 0:00:010:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 345.4/345.4 kB 489.6 kB/s eta 0:00:001m482.1 kB/s eta 0:00:01
# ...

# %%
import pandas as pd

# %%
# !pip install faker
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 1.5 MB/s eta 0:00:00m eta 0:00:010:01:010m
# ...

# %%
from faker import Faker
fake = Faker()

# %%
lista = []

# %%
for x in range(0,51):
    lista.append({'nombre': fake.name()})

# %%
lista
# Out:
# [{'nombre': 'Tiffany Harrison'},
#  {'nombre': 'Dr. Allison Woodard'},
#  {'nombre': 'Norma Dougherty'},
#  {'nombre': 'Robert Hale'},
#  {'nombre': 'Jeffrey Hernandez'},
#  {'nombre': 'Sean Brown'},
#  {'nombre': 'Thomas Glover'},
#  {'nombre': 'Leonard Page'},
#  {'nombre': 'Richard Jacobs'},
#  {'nombre': 'Rebecca Middleton'},
#  {'nombre': 'Kristina Martin'},
#  {'nombre': 'Samantha Hancock'},
#  {'nombre': 'Devin Manning'},
#  {'nombre': 'Rachel Roman'},
#  {'nombre': 'Eric Rowe'},
#  {'nombre': 'Phillip Miller'},
#  {'nombre': 'Christian Peterson'},
#  {'nombre': 'Denise Solomon'},
#  {'nombre': 'Terry Jones'},
#  {'nombre': 'Colleen King'},
#  {'nombre': 'James Perkins'},
#  {'nombre': 'Anne Mendoza'},
#  {'nombre': 'Donald Guzman'},
#  {'nombre': 'William Newman'},
#  {'nombre': 'Sandra Greene'},
#  {'nombre': 'Julie Bradford'},
#  {'nombre': 'Benjamin Walsh'},
#  {'nombre': 'Oscar Hall'},
#  {'nombre': 'Jennifer Rodriguez'},
#  {'nombre': 'Daniel Foster'},
# ...

# %%
data = pd.DataFrame(lista)

# %%
data
# Out:
#                  nombre
# 0      Tiffany Harrison
# 1   Dr. Allison Woodard
# 2       Norma Dougherty
# 3           Robert Hale
# 4     Jeffrey Hernandez
# 5            Sean Brown
# 6         Thomas Glover
# 7          Leonard Page
# 8        Richard Jacobs
# 9     Rebecca Middleton
# 10      Kristina Martin
# 11     Samantha Hancock
# 12        Devin Manning
# 13         Rachel Roman
# 14            Eric Rowe
# 15       Phillip Miller
# 16   Christian Peterson
# 17       Denise Solomon
# 18          Terry Jones
# 19         Colleen King
# 20        James Perkins
# 21         Anne Mendoza
# 22        Donald Guzman
# 23       William Newman
# 24        Sandra Greene
# 25       Julie Bradford
# 26       Benjamin Walsh
# 27           Oscar Hall
# 28   Jennifer Rodriguez
# 29        Daniel Foster
# 30      Brittany Howell
# 31     Elizabeth Prince
# 32        Kyle Calderon
# 33        Emily Schmidt
# 34     Nicole Velazquez
# 35           Gina Rivas
# 36           Kathryn Li
# ...

# %%
data.to_csv("misdata.csv", index=False)
