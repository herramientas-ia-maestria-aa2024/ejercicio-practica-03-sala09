# %%
import pandas as pd

# %%
data = pd.read_csv("misdata.csv")

# %%
data
# Out:
#                  nombre
# 0      Tiffany Harrison
# 1   Dr. Allison Woodard
# 2       Norma Dougherty
# 3           Robert Hale
# 4     Jeffrey Hernandez
# 5            Sean Brown
# 6         Thomas Glover
# 7          Leonard Page
# 8        Richard Jacobs
# 9     Rebecca Middleton
# 10      Kristina Martin
# 11     Samantha Hancock
# 12        Devin Manning
# 13         Rachel Roman
# 14            Eric Rowe
# 15       Phillip Miller
# 16   Christian Peterson
# 17       Denise Solomon
# 18          Terry Jones
# 19         Colleen King
# 20        James Perkins
# 21         Anne Mendoza
# 22        Donald Guzman
# 23       William Newman
# 24        Sandra Greene
# 25       Julie Bradford
# 26       Benjamin Walsh
# 27           Oscar Hall
# 28   Jennifer Rodriguez
# 29        Daniel Foster
# 30      Brittany Howell
# 31     Elizabeth Prince
# 32        Kyle Calderon
# 33        Emily Schmidt
# 34     Nicole Velazquez
# 35           Gina Rivas
# 36           Kathryn Li
# ...

# %%
def obtener_inicial(d):
    cadena = d[0]
    return cadena

# %%
def obtener_mayuscula(d):
    cadena = d.upper()
    return cadena

# %%
data['inicial'] = data['nombre'].apply(obtener_inicial)

# %%
data
# Out:
#                  nombre inicial
# 0      Tiffany Harrison       T
# 1   Dr. Allison Woodard       D
# 2       Norma Dougherty       N
# 3           Robert Hale       R
# 4     Jeffrey Hernandez       J
# 5            Sean Brown       S
# 6         Thomas Glover       T
# 7          Leonard Page       L
# 8        Richard Jacobs       R
# 9     Rebecca Middleton       R
# 10      Kristina Martin       K
# 11     Samantha Hancock       S
# 12        Devin Manning       D
# 13         Rachel Roman       R
# 14            Eric Rowe       E
# 15       Phillip Miller       P
# 16   Christian Peterson       C
# 17       Denise Solomon       D
# 18          Terry Jones       T
# 19         Colleen King       C
# 20        James Perkins       J
# 21         Anne Mendoza       A
# 22        Donald Guzman       D
# 23       William Newman       W
# 24        Sandra Greene       S
# 25       Julie Bradford       J
# 26       Benjamin Walsh       B
# 27           Oscar Hall       O
# ...

# %%
data['mayuscula'] = data['nombre'].apply(obtener_mayuscula)

# %%
data
# Out:
#                  nombre inicial            mayuscula
# 0      Tiffany Harrison       T     TIFFANY HARRISON
# 1   Dr. Allison Woodard       D  DR. ALLISON WOODARD
# 2       Norma Dougherty       N      NORMA DOUGHERTY
# 3           Robert Hale       R          ROBERT HALE
# 4     Jeffrey Hernandez       J    JEFFREY HERNANDEZ
# 5            Sean Brown       S           SEAN BROWN
# 6         Thomas Glover       T        THOMAS GLOVER
# 7          Leonard Page       L         LEONARD PAGE
# 8        Richard Jacobs       R       RICHARD JACOBS
# 9     Rebecca Middleton       R    REBECCA MIDDLETON
# 10      Kristina Martin       K      KRISTINA MARTIN
# 11     Samantha Hancock       S     SAMANTHA HANCOCK
# 12        Devin Manning       D        DEVIN MANNING
# 13         Rachel Roman       R         RACHEL ROMAN
# 14            Eric Rowe       E            ERIC ROWE
# 15       Phillip Miller       P       PHILLIP MILLER
# 16   Christian Peterson       C   CHRISTIAN PETERSON
# ...

# %%
data.to_csv("misdata2.csv")
