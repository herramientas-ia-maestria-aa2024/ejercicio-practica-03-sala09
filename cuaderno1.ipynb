# %%
import pandas as pd

# %%
from faker import Faker
fake = Faker()

# %%
lista = []

# %%
for x in range(0,1000):
    lista.append({'nombre': fake.name(),'last_name': fake.last_name(),'email': fake.email(),'address': fake.address()})

# %%
lista
# Out:
# [{'nombre': 'Linda Wilson',
#   'last_name': 'Alvarez',
#   'email': 'jamesstone@example.com',
#   'address': '432 John Stravenue Suite 335\nSouth Allisonburgh, GU 23682'},
#  {'nombre': 'Evan Jones',
#   'last_name': 'Parker',
#   'email': 'garciachristine@example.net',
#   'address': '415 Stephanie Isle\nVeronicatown, GU 41545'},
#  {'nombre': 'Shelby Johnson',
#   'last_name': 'Burch',
#   'email': 'ehale@example.com',
#   'address': '4771 Mcclain Expressway Apt. 432\nWest Hannahfurt, NE 34504'},
#  {'nombre': 'Patrick Kennedy',
#   'last_name': 'Baker',
#   'email': 'wmartinez@example.com',
#   'address': '9355 Robert Canyon Apt. 276\nFloresshire, SD 13459'},
#  {'nombre': 'Jamie Dennis',
#   'last_name': 'Lewis',
#   'email': 'gonzalesjohn@example.org',
#   'address': '43369 Harris Common Suite 132\nRyanland, MI 02199'},
#  {'nombre': 'Andrew Hayes',
#   'last_name': 'Brown',
#   'email': 'jorge44@example.com',
#   'address': 'PSC 6542, Box 0220\nAPO AA 64777'},
# ...

# %%
data = pd.DataFrame(lista)

# %%
data
# Out:
#               nombre last_name                        email  \
# 0       Linda Wilson   Alvarez       jamesstone@example.com
# 1         Evan Jones    Parker  garciachristine@example.net
# 2     Shelby Johnson     Burch            ehale@example.com
# 3    Patrick Kennedy     Baker        wmartinez@example.com
# 4       Jamie Dennis     Lewis     gonzalesjohn@example.org
# ..               ...       ...                          ...
# 995     Gina Spencer    Ortega         balvarez@example.net
# 996        John Khan      Diaz     lopezmatthew@example.net
# 997    Austin Powell      Kent        tiffany07@example.org
# 998    Monica Mosley   Miranda   nguyenkathleen@example.org
# 999  Thomas Robinson     Woods    brownjennifer@example.org
#
#                                                address
# 0    432 John Stravenue Suite 335\nSouth Allisonbur...
# 1           415 Stephanie Isle\nVeronicatown, GU 41545
# 2    4771 Mcclain Expressway Apt. 432\nWest Hannahf...
# ...

# %%
import numpy as np

# %%
data['Edad']= np.random.randint(30,41,size=len(data))

# %%
provincias = ['Loja', 'Pichincha', 'Guayas', 'Azuay', 'Manabí']

# %%
data['Provincia']= np.random.choice(provincias,size=1000)

# %%
data
# Out:
#               nombre last_name                        email  \
# 0       Linda Wilson   Alvarez       jamesstone@example.com
# 1         Evan Jones    Parker  garciachristine@example.net
# 2     Shelby Johnson     Burch            ehale@example.com
# 3    Patrick Kennedy     Baker        wmartinez@example.com
# 4       Jamie Dennis     Lewis     gonzalesjohn@example.org
# ..               ...       ...                          ...
# 995     Gina Spencer    Ortega         balvarez@example.net
# 996        John Khan      Diaz     lopezmatthew@example.net
# 997    Austin Powell      Kent        tiffany07@example.org
# 998    Monica Mosley   Miranda   nguyenkathleen@example.org
# 999  Thomas Robinson     Woods    brownjennifer@example.org
#
#                                                address  Edad  Provincia
# 0    432 John Stravenue Suite 335\nSouth Allisonbur...    31     Guayas
# 1           415 Stephanie Isle\nVeronicatown, GU 41545    30       Loja
# ...

# %%
data.to_csv("datos_ejercicio.csv", index=False)
